# %%
## Este Notebook es de prueba, para notar si funciona la conexion local
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from goalguru.lib import who_am_i
who_am_i()
# Out:
# Hello my name is Jean

# %%
import pandas as pd



data_soccer = pd.DataFrame([
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_3'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_1'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_2'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_3'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_4'},    
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_5'},    
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_6'},    
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_7'},    
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_8'},    


    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_3'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_4'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_5'},      
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_1'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_2'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_3'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_4'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_5'},    
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_6'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_7'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_8'},    
    
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_3'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_4'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_1'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_2'},    
    ])

data_stats = pd.DataFrame([
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_1'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_2'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_3'},
    {'competition_id': 0, 'name': 'Premier League' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_4'},    
   


    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_3'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_1'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_2'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_3'},
    {'competition_id': 1, 'name': 'Serie A' , 'season_id': 1, 'season': '2017/2018','match': 'match_4'},
    
    
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_1'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_2'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_3'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_4'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_5'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_6'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 0, 'season': '2016/2017', 'match': 'match_7'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_1'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_2'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_3'},
    {'competition_id': 2, 'name': 'Bundesliga' , 'season_id': 1, 'season': '2017/2018', 'match': 'match_4'},    
    ])

data_stats
# Out:
#     competition_id            name  season_id     season    match
# 0                0  Premier League          0  2016/2017  match_1
# 1                0  Premier League          0  2016/2017  match_2
# 2                0  Premier League          1  2017/2018  match_1
# 3                0  Premier League          1  2017/2018  match_2
# 4                0  Premier League          1  2017/2018  match_3
# 5                0  Premier League          1  2017/2018  match_4
# 6                1         Serie A          0  2016/2017  match_1
# 7                1         Serie A          0  2016/2017  match_2
# 8                1         Serie A          0  2016/2017  match_3
# 9                1         Serie A          1  2017/2018  match_1
# 10               1         Serie A          1  2017/2018  match_2
# 11               1         Serie A          1  2017/2018  match_3
# 12               1         Serie A          1  2017/2018  match_4
# 13               2      Bundesliga          0  2016/2017  match_1
# 14               2      Bundesliga          0  2016/2017  match_2
# 15               2      Bundesliga          0  2016/2017  match_3
# 16               2      Bundesliga          0  2016/2017  match_4
# 17               2      Bundesliga          0  2016/2017  match_5
# 18               2      Bundesliga          0  2016/2017  match_6
# 19               2      Bundesliga          0  2016/2017  match_7
# 20               2      Bundesliga          1  2017/2018  match_1
# 21               2      Bundesliga          1  2017/2018  match_2
# 22               2      Bundesliga          1  2017/2018  match_3
# 23               2      Bundesliga          1  2017/2018  match_4

# %%
data_soccer
# Out:
#     competition_id            name  season_id     season    match
# 0                0  Premier League          0  2016/2017  match_1
# 1                0  Premier League          0  2016/2017  match_2
# 2                0  Premier League          0  2016/2017  match_3
# 3                0  Premier League          1  2017/2018  match_1
# 4                0  Premier League          1  2017/2018  match_2
# 5                0  Premier League          1  2017/2018  match_3
# 6                0  Premier League          1  2017/2018  match_4
# 7                0  Premier League          1  2017/2018  match_5
# 8                0  Premier League          1  2017/2018  match_6
# 9                0  Premier League          1  2017/2018  match_7
# 10               0  Premier League          1  2017/2018  match_8
# 11               1         Serie A          0  2016/2017  match_1
# 12               1         Serie A          0  2016/2017  match_2
# 13               1         Serie A          0  2016/2017  match_3
# 14               1         Serie A          0  2016/2017  match_4
# 15               1         Serie A          0  2016/2017  match_5
# 16               1         Serie A          1  2017/2018  match_1
# 17               1         Serie A          1  2017/2018  match_2
# 18               1         Serie A          1  2017/2018  match_3
# 19               1         Serie A          1  2017/2018  match_4
# 20               1         Serie A          1  2017/2018  match_5
# 21               1         Serie A          1  2017/2018  match_6
# 22               1         Serie A          1  2017/2018  match_7
# 23               1         Serie A          1  2017/2018  match_8
# 24               2      Bundesliga          0  2016/2017  match_1
# 25               2      Bundesliga          0  2016/2017  match_2
# 26               2      Bundesliga          0  2016/2017  match_3
# 27               2      Bundesliga          0  2016/2017  match_4
# 28               2      Bundesliga          1  2017/2018  match_1
# 29               2      Bundesliga          1  2017/2018  match_2

# %%
def get_competitions(data):
    # Group the DataFrame by 'competition_id' and 'name' columns and aggregate them
    grouped_data = data.groupby(['competition_id', 'name']).size().reset_index(name='count')

    # Convert the grouped DataFrame to a list of dictionaries
    competition_list = [{'competition_id': row['competition_id'], 'name': row['name']} for index, row in grouped_data.iterrows()]

    return competition_list

get_competitions(data)
# Out:
# [{'competition_id': 0, 'name': 'Premier League'},
#  {'competition_id': 1, 'name': 'Serie A'},
#  {'competition_id': 2, 'name': 'Bundesliga'}]

# %%
def get_seasons(competition_id):
    
    
    data=data
    
    # Filter the DataFrame based on the given competition_id
    filtered_data = data[data['competition_id'] == competition_id]
    
  # Check if there is data for the given competition_id
    if filtered_data.empty:
        return print("No data for the provided competition_id.")   
    
    # Get unique season IDs for the selected competition
    unique_seasons = filtered_data['season_id'].unique()

    # Create a list of dictionaries for each unique season
    seasons_list = [
        {
            'season_id': season_id,
            'season': filtered_data[filtered_data['season_id'] == season_id]['season'].iloc[0],
            'matchweeks': list(range(len(filtered_data[filtered_data['season_id'] == season_id])))
        }
        for season_id in unique_seasons
    ]

    return seasons_list

get_seasons(competition_id=2)
# Out:
# [{'season_id': 0, 'season': '2016/2017', 'matchweeks': [0, 1, 2, 3]},
#  {'season_id': 1, 'season': '2017/2018', 'matchweeks': [0, 1]}]

# %%
## NO ESTA BUENA. hay que seguir trabajandola


competition_to_dataset = {
    0: 'soccermatch',
    1: 'statsbomb',
    # Add more mappings as needed
    # Add mappings for other competition_ids and datasets
}

def get_seasons(competition_id, data_soccer, data_stats):
    # Filter the DataFrame based on the given competition_id for both datasets
    filtered_data_soccer = data_soccer[data_soccer['competition_id'] == competition_id]
    filtered_data_stats = data_stats[data_stats['competition_id'] == competition_id]
    
    # Check if there is data for the given competition_id in both datasets
    if filtered_data_soccer.empty and filtered_data_stats.empty:
        return None

    # Initialize an empty list to store combined season information
    combined_seasons = []

    # Get unique season IDs for the selected competition in both datasets
    unique_seasons_soccer = filtered_data_soccer['season_id'].unique()
    unique_seasons_stats = filtered_data_stats['season_id'].unique()

    # Create a list of dictionaries for each unique season in the soccer dataset
    seasons_soccer = [
        {
            'season_id': season_id,
            'season': filtered_data_soccer[filtered_data_soccer['season_id'] == season_id]['season'].iloc[0],
            'matchweeks': list(range(1, len(filtered_data_soccer[filtered_data_soccer['season_id'] == season_id]) + 1)),
            'dataset': competition_to_dataset.get(competition_id, 'unknown')
        }
        for season_id in unique_seasons_soccer
    ]

    # Append soccer dataset season information to the combined list
    combined_seasons.extend(seasons_soccer)

    # Create a list of dictionaries for each unique season in the stats dataset
    seasons_stats = [
        {
            'season_id': season_id,
            'season': filtered_data_stats[filtered_data_stats['season_id'] == season_id]['season'].iloc[0],
            'matchweeks': list(range(1, len(filtered_data_stats[filtered_data_stats['season_id'] == season_id]) + 1)),
            'dataset': competition_to_dataset.get(competition_id, 'unknown')
        }
        for season_id in unique_seasons_stats
    ]

    # Append stats dataset season information to the combined list
    combined_seasons.extend(seasons_stats)

    return combined_seasons

get_seasons(competition_id=1, data_soccer=data_soccer, data_stats=data_stats)
# Out:
# [{'season_id': 0,
#   'season': '2016/2017',
#   'matchweeks': [1, 2, 3, 4, 5],
#   'dataset': 'statsbomb'},
#  {'season_id': 1,
#   'season': '2017/2018',
#   'matchweeks': [1, 2, 3, 4, 5, 6, 7, 8],
#   'dataset': 'statsbomb'},
#  {'season_id': 0,
#   'season': '2016/2017',
#   'matchweeks': [1, 2, 3],
#   'dataset': 'statsbomb'},
#  {'season_id': 1,
#   'season': '2017/2018',
#   'matchweeks': [1, 2, 3, 4],
#   'dataset': 'statsbomb'}]
